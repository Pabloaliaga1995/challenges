# %% [markdown]
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# imports
import pandas as pd
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` a generate your __token__ access

# %%
# generate token with a POST request

client_id = 'a27687307e844539aa43816a9593ec0e'
client_secret = 'ca9a8573d57c438383162db76e8722b1'
auth_url = 'https://accounts.spotify.com/api/token'

auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()
#Estos son los headers
access_token = auth_response['access_token']
access_token
#Este access_token es uno de los elementos que incluye el json que trae.
# Out:
# 'BQCzyjjbtz4Vhk4mMtVH0hJOdtDW0V6o_Vob4sktOIWZbfmEl5vFFJ63kRcqwzvZaZ4-L7nwmHI3BrMRG2k'

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_url` (i.e.: End-point) and `headers` for your __GET__ operations

# %%
# setting the main variables

base_url = 'https://api.spotify.com/v1'
resource = '/artists/'
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}
headers
# Out:
# {'Authorization': 'Bearer BQCzyjjbtz4Vhk4mMtVH0hJOdtDW0V6o_Vob4sktOIWZbfmEl5vFFJ63kRcqwzvZaZ4-L7nwmHI3BrMRG2k'}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need
#
# __Here you have the different artists to start with:__
#
# _Option 1:_ 711MCceyCBcFnzjGY4Q7Un
#
# _Option 2:_ 5gs3QMiBgkUgNofeA16Awv
#
# _Option 3:_ 1ZcvF2meiXi5UPDJWxrKR5
#
# _Option 4:_ 0HSGpDMeXaEmH5aUIHjnBF
#
# _Option 5:_ 5TYxZTjIPqKM8K8NuP9woO
#
# _Option 6:_ 36QJpDe2go2KgaRleHCDTp
#
# _Option 7:_ 3qm84nBOXUEQ2vnTfUTTFC
#
# _Option 8:_ 4NJhFmfw43RLBLjQvxDuRS
#
# _Option 9:_ 0L8ExT028jH3ddEcZwqJJ5
#
# _Option 10:_ 1vCWHaC5f2uS3yhpwWbIA6
#
# _Option 11:_ 1dfeR4HaWDbWqFHLkxsg1d
#
# _Option 12:_ 6ogn9necmbUdCppmNnGOdi

# %%
# your code
artist_id = '1vCWHaC5f2uS3yhpwWbIA6'
action = '/related-artists'

url1 = base_url + resource + artist_id + action
url1
# Out:
# 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6/related-artists'

# %%
related_artists = requests.get(url1, headers = headers)
related_artists
# Out:
# <Response [200]>

# %%
related_artists_json = related_artists.json()
related_artists_json
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#    'followers': {'href': None, 'total': 3769430},
#    'genres': ['big room',
#     'dance pop',
#     'dutch house',
#     'edm',
#     'electro house',
#     'pop dance',
#     'pop rap',
#     'progressive house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#    'id': '4D75GcNG95ebPtNvoNVXhz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb549aa0ce64b4b9797b24e3be',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174549aa0ce64b4b9797b24e3be',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178549aa0ce64b4b9797b24e3be',
#      'width': 160}],
#    'name': 'Afrojack',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#    'followers': {'href': None, 'total': 3725109},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'progressive electro house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#    'id': '4AVFqumd2ogHFlRbKIjp1t',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb9af50fc064002b6c714f6fcc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051749af50fc064002b6c714f6fcc',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1789af50fc064002b6c714f6fcc',
#      'width': 160}],
#    'name': 'Alesso',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6BrvowZBreEkXzJQMpL174'},
#    'followers': {'href': None, 'total': 3530078},
#    'genres': ['big room',
#     'dance pop',
#     'dutch house',
#     'edm',
#     'electro house',
#     'pop dance',
#     'progressive electro house',
#     'progressive house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/6BrvowZBreEkXzJQMpL174',
#    'id': '6BrvowZBreEkXzJQMpL174',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebe22cdcc7ae21736085667980',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174e22cdcc7ae21736085667980',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178e22cdcc7ae21736085667980',
#      'width': 160}],
#    'name': 'Hardwell',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:6BrvowZBreEkXzJQMpL174'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1h6Cn3P4NGzXbaXidqURXs'},
#    'followers': {'href': None, 'total': 3440200},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'progressive electro house'],
#    'href': 'https://api.spotify.com/v1/artists/1h6Cn3P4NGzXbaXidqURXs',
#    'id': '1h6Cn3P4NGzXbaXidqURXs',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb0c05adcae61ac479afe35c8e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051740c05adcae61ac479afe35c8e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1780c05adcae61ac479afe35c8e',
#      'width': 160}],
#    'name': 'Swedish House Mafia',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:1h6Cn3P4NGzXbaXidqURXs'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ChF3i92IPZHduM7jN3dpg'},
#    'followers': {'href': None, 'total': 2126172},
#    'genres': ['big room',
#     'dance pop',
#     'dutch edm',
#     'dutch house',
#     'edm',
#     'electro house',
#     'pop dance',
#     'pop edm',
#     'progressive electro house',
#     'progressive house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/5ChF3i92IPZHduM7jN3dpg',
#    'id': '5ChF3i92IPZHduM7jN3dpg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb210359367a4772415e621987',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174210359367a4772415e621987',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178210359367a4772415e621987',
#      'width': 160}],
#    'name': 'Nicky Romero',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:5ChF3i92IPZHduM7jN3dpg'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2qxJFvFYMEDqd7ui6kSAcq'},
#    'followers': {'href': None, 'total': 5626382},
#    'genres': ['complextro',
#     'dance pop',
#     'edm',
#     'electro house',
#     'electropop',
#     'german techno',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/2qxJFvFYMEDqd7ui6kSAcq',
#    'id': '2qxJFvFYMEDqd7ui6kSAcq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebcbe6db0e826f9e816a7d158e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174cbe6db0e826f9e816a7d158e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178cbe6db0e826f9e816a7d158e',
#      'width': 160}],
#    'name': 'Zedd',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:2qxJFvFYMEDqd7ui6kSAcq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2XnBwblw31dfGnspMIwgWz'},
#    'followers': {'href': None, 'total': 2341040},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/2XnBwblw31dfGnspMIwgWz',
#    'id': '2XnBwblw31dfGnspMIwgWz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb9f6e5d736809c4cb40d59a7e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051749f6e5d736809c4cb40d59a7e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1789f6e5d736809c4cb40d59a7e',
#      'width': 160}],
#    'name': 'Axwell /\\ Ingrosso',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:2XnBwblw31dfGnspMIwgWz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4sTQVOfp9vEMCemLw50sbu'},
#    'followers': {'href': None, 'total': 3166621},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/4sTQVOfp9vEMCemLw50sbu',
#    'id': '4sTQVOfp9vEMCemLw50sbu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb29fc429af2f3a752aa57d94d',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517429fc429af2f3a752aa57d94d',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17829fc429af2f3a752aa57d94d',
#      'width': 160}],
#    'name': 'Galantis',
#    'popularity': 78,
#    'type': 'artist',
#    'uri': 'spotify:artist:4sTQVOfp9vEMCemLw50sbu'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HBjj22wzbscIZ9sEb5dyf'},
#    'followers': {'href': None, 'total': 3422482},
#    'genres': ['dance pop',
#     'edm',
#     'pop',
#     'pop dance',
#     'tropical house',
#     'uk dance'],
#    'href': 'https://api.spotify.com/v1/artists/1HBjj22wzbscIZ9sEb5dyf',
#    'id': '1HBjj22wzbscIZ9sEb5dyf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb9b22a34af699b8cde5543d56',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051749b22a34af699b8cde5543d56',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1789b22a34af699b8cde5543d56',
#      'width': 160}],
#    'name': 'Jonas Blue',
#    'popularity': 78,
#    'type': 'artist',
#    'uri': 'spotify:artist:1HBjj22wzbscIZ9sEb5dyf'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/60d24wfXkVzDSfLS6hyCjZ'},
#    'followers': {'href': None, 'total': 15241399},
#    'genres': ['dance pop',
#     'dutch edm',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'progressive house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/60d24wfXkVzDSfLS6hyCjZ',
#    'id': '60d24wfXkVzDSfLS6hyCjZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb66d17ee8690d2e8d94ee7387',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517466d17ee8690d2e8d94ee7387',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17866d17ee8690d2e8d94ee7387',
#      'width': 160}],
#    'name': 'Martin Garrix',
#    'popularity': 80,
#    'type': 'artist',
#    'uri': 'spotify:artist:60d24wfXkVzDSfLS6hyCjZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6lB8vOoI4DRrrVxXwuV19c'},
#    'followers': {'href': None, 'total': 1272183},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'swedish tropical house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/6lB8vOoI4DRrrVxXwuV19c',
#    'id': '6lB8vOoI4DRrrVxXwuV19c',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb4ca7ccebc2f9e6c281cd6ff3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051744ca7ccebc2f9e6c281cd6ff3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1784ca7ccebc2f9e6c281cd6ff3',
#      'width': 160}],
#    'name': 'Mike Perry',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:6lB8vOoI4DRrrVxXwuV19c'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ehtJnVumNf6xzSCDk8aLB'},
#    'followers': {'href': None, 'total': 1179002},
#    'genres': ['dance pop',
#     'danish electronic',
#     'deep house',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/4ehtJnVumNf6xzSCDk8aLB',
#    'id': '4ehtJnVumNf6xzSCDk8aLB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb48c528354d579d31d5cd7544',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517448c528354d579d31d5cd7544',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17848c528354d579d31d5cd7544',
#      'width': 160}],
#    'name': 'Martin Jensen',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:4ehtJnVumNf6xzSCDk8aLB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6hyMWrxGBsOx6sWcVj1DqP'},
#    'followers': {'href': None, 'total': 912482},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop dance',
#     'progressive electro house',
#     'progressive house'],
#    'href': 'https://api.spotify.com/v1/artists/6hyMWrxGBsOx6sWcVj1DqP',
#    'id': '6hyMWrxGBsOx6sWcVj1DqP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb768afab7f79b0c4f9924c2fa',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174768afab7f79b0c4f9924c2fa',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178768afab7f79b0c4f9924c2fa',
#      'width': 160}],
#    'name': 'Sebastian Ingrosso',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:6hyMWrxGBsOx6sWcVj1DqP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wwneIFdawNgQ7GvKK29Z3'},
#    'followers': {'href': None, 'total': 402966},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop dance',
#     'pop edm',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/5wwneIFdawNgQ7GvKK29Z3',
#    'id': '5wwneIFdawNgQ7GvKK29Z3',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb470813301c86701f77d67437',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174470813301c86701f77d67437',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178470813301c86701f77d67437',
#      'width': 160}],
#    'name': 'Lucas & Steve',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:5wwneIFdawNgQ7GvKK29Z3'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tLYpanVDomWAZqF82NPds'},
#    'followers': {'href': None, 'total': 261326},
#    'genres': ['dance pop',
#     'edm',
#     'electronic trap',
#     'pop dance',
#     'pop rap',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/3tLYpanVDomWAZqF82NPds',
#    'id': '3tLYpanVDomWAZqF82NPds',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb721f4065b22c51140737289f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174721f4065b22c51140737289f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178721f4065b22c51140737289f',
#      'width': 160}],
#    'name': 'Vigiland',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:3tLYpanVDomWAZqF82NPds'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#    'followers': {'href': None, 'total': 2284420},
#    'genres': ['dance pop',
#     'dutch house',
#     'edm',
#     'electro house',
#     'pop',
#     'pop dance',
#     'progressive electro house',
#     'slap house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#    'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb67828d8c05c5e2acf8f03e1e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517467828d8c05c5e2acf8f03e1e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17867828d8c05c5e2acf8f03e1e',
#      'width': 160}],
#    'name': 'R3HAB',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1l2ekx5skC4gJH8djERwh1'},
#    'followers': {'href': None, 'total': 1767931},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'future house',
#     'house',
#     'pop dance',
#     'progressive electro house',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/1l2ekx5skC4gJH8djERwh1',
#    'id': '1l2ekx5skC4gJH8djERwh1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebd0c6f816e695c39b0cbb22c3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174d0c6f816e695c39b0cbb22c3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178d0c6f816e695c39b0cbb22c3',
#      'width': 160}],
#    'name': 'Don Diablo',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:1l2ekx5skC4gJH8djERwh1'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bj5GrcLom5gZFF5t949Xl'},
#    'followers': {'href': None, 'total': 1190350},
#    'genres': ['dance pop',
#     'disco house',
#     'edm',
#     'electro house',
#     'filter house',
#     'house',
#     'pop dance',
#     'tropical house',
#     'vocal house'],
#    'href': 'https://api.spotify.com/v1/artists/1bj5GrcLom5gZFF5t949Xl',
#    'id': '1bj5GrcLom5gZFF5t949Xl',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb2d6fb5d94a32063560e07014',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051742d6fb5d94a32063560e07014',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1782d6fb5d94a32063560e07014',
#      'width': 160}],
#    'name': 'Martin Solveig',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:1bj5GrcLom5gZFF5t949Xl'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/77AiFEVeAVj2ORpC85QVJs'},
#    'followers': {'href': None, 'total': 3613291},
#    'genres': ['dance pop',
#     'edm',
#     'electro house',
#     'pop dance',
#     'pop rap',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/77AiFEVeAVj2ORpC85QVJs',
#    'id': '77AiFEVeAVj2ORpC85QVJs',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb7c4240b7951da248f3404e42',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051747c4240b7951da248f3404e42',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1787c4240b7951da248f3404e42',
#      'width': 160}],
#    'name': 'Steve Aoki',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:77AiFEVeAVj2ORpC85QVJs'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#    'followers': {'href': None, 'total': 1355836},
#    'genres': ['dance pop', 'edm', 'pop', 'pop dance', 'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#    'id': '1IueXOQyABrMOprrzwQJWN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb8422afa6e7b0c977636bfebd',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051748422afa6e7b0c977636bfebd',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1788422afa6e7b0c977636bfebd',
#      'width': 160}],
#    'name': 'Sigala',
#    'popularity': 75,
#    'type': 'artist',
#    'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}]}

# %%
related_artists_df=pd.DataFrame(related_artists_json["artists"])
related_artists_df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/4...
# 1  {'spotify': 'https://open.spotify.com/artist/4...
# 2  {'spotify': 'https://open.spotify.com/artist/6...
# 3  {'spotify': 'https://open.spotify.com/artist/1...
# 4  {'spotify': 'https://open.spotify.com/artist/5...
#
#                           followers  \
# 0  {'href': None, 'total': 3769430}
# 1  {'href': None, 'total': 3725109}
# 2  {'href': None, 'total': 3530078}
# 3  {'href': None, 'total': 3440200}
# 4  {'href': None, 'total': 2126172}
#
#                                               genres  \
# 0  [big room, dance pop, dutch house, edm, electr...
# 1  [dance pop, edm, electro house, pop, pop dance...
# 2  [big room, dance pop, dutch house, edm, electr...
# 3  [dance pop, edm, electro house, pop, pop dance...
# 4  [big room, dance pop, dutch edm, dutch house, ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/4D75GcNG95e...  4D75GcNG95ebPtNvoNVXhz
# 1  https://api.spotify.com/v1/artists/4AVFqumd2og...  4AVFqumd2ogHFlRbKIjp1t
# 2  https://api.spotify.com/v1/artists/6BrvowZBreE...  6BrvowZBreEkXzJQMpL174
# 3  https://api.spotify.com/v1/artists/1h6Cn3P4NGz...  1h6Cn3P4NGzXbaXidqURXs
# 4  https://api.spotify.com/v1/artists/5ChF3i92IPZ...  5ChF3i92IPZHduM7jN3dpg
#
#                                               images                 name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...             Afrojack
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...               Alesso
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...             Hardwell
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Swedish House Mafia
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...         Nicky Romero
#
#    popularity    type                                    uri
# 0          77  artist  spotify:artist:4D75GcNG95ebPtNvoNVXhz
# 1          77  artist  spotify:artist:4AVFqumd2ogHFlRbKIjp1t
# 2          68  artist  spotify:artist:6BrvowZBreEkXzJQMpL174
# 3          79  artist  spotify:artist:1h6Cn3P4NGzXbaXidqURXs
# 4          68  artist  spotify:artist:5ChF3i92IPZHduM7jN3dpg

# %%
rel_artist = related_artists_df['id']
rel_artist
# Out:
# 0     4D75GcNG95ebPtNvoNVXhz
# 1     4AVFqumd2ogHFlRbKIjp1t
# 2     6BrvowZBreEkXzJQMpL174
# 3     1h6Cn3P4NGzXbaXidqURXs
# 4     5ChF3i92IPZHduM7jN3dpg
# 5     2qxJFvFYMEDqd7ui6kSAcq
# 6     2XnBwblw31dfGnspMIwgWz
# 7     4sTQVOfp9vEMCemLw50sbu
# 8     1HBjj22wzbscIZ9sEb5dyf
# 9     60d24wfXkVzDSfLS6hyCjZ
# 10    6lB8vOoI4DRrrVxXwuV19c
# 11    4ehtJnVumNf6xzSCDk8aLB
# 12    6hyMWrxGBsOx6sWcVj1DqP
# 13    5wwneIFdawNgQ7GvKK29Z3
# 14    3tLYpanVDomWAZqF82NPds
# 15    6cEuCEZu7PAE9ZSzLLc2oQ
# 16    1l2ekx5skC4gJH8djERwh1
# 17    1bj5GrcLom5gZFF5t949Xl
# 18    77AiFEVeAVj2ORpC85QVJs
# 19    1IueXOQyABrMOprrzwQJWN
# Name: id, dtype: object

# %%
rel_artist = list(rel_artist)
rel_artist
# Out:
# ['4D75GcNG95ebPtNvoNVXhz',
#  '4AVFqumd2ogHFlRbKIjp1t',
#  '6BrvowZBreEkXzJQMpL174',
#  '1h6Cn3P4NGzXbaXidqURXs',
#  '5ChF3i92IPZHduM7jN3dpg',
#  '2qxJFvFYMEDqd7ui6kSAcq',
#  '2XnBwblw31dfGnspMIwgWz',
#  '4sTQVOfp9vEMCemLw50sbu',
#  '1HBjj22wzbscIZ9sEb5dyf',
#  '60d24wfXkVzDSfLS6hyCjZ',
#  '6lB8vOoI4DRrrVxXwuV19c',
#  '4ehtJnVumNf6xzSCDk8aLB',
#  '6hyMWrxGBsOx6sWcVj1DqP',
#  '5wwneIFdawNgQ7GvKK29Z3',
#  '3tLYpanVDomWAZqF82NPds',
#  '6cEuCEZu7PAE9ZSzLLc2oQ',
#  '1l2ekx5skC4gJH8djERwh1',
#  '1bj5GrcLom5gZFF5t949Xl',
#  '77AiFEVeAVj2ORpC85QVJs',
#  '1IueXOQyABrMOprrzwQJWN']

# %%
top_tracks = []
for i in rel_artist:
    artist_id2 = i
    action2 = '/top-tracks?market=ES'
    url2 = base_url + resource + artist_id2 + action2
    print(url2)
    top_tr = requests.get(url2, headers = headers).json()
    top_tracks.append(top_tr)

top_tracks
# Out:
# https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz/top-tracks?market=ES
# https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t/top-tracks?market=ES
# https://api.spotify.com/v1/artists/6BrvowZBreEkXzJQMpL174/top-tracks?market=ES
# https://api.spotify.com/v1/artists/1h6Cn3P4NGzXbaXidqURXs/top-tracks?market=ES
# https://api.spotify.com/v1/artists/5ChF3i92IPZHduM7jN3dpg/top-tracks?market=ES
# https://api.spotify.com/v1/artists/2qxJFvFYMEDqd7ui6kSAcq/top-tracks?market=ES
# https://api.spotify.com/v1/artists/2XnBwblw31dfGnspMIwgWz/top-tracks?market=ES
# https://api.spotify.com/v1/artists/4sTQVOfp9vEMCemLw50sbu/top-tracks?market=ES
# https://api.spotify.com/v1/artists/1HBjj22wzbscIZ9sEb5dyf/top-tracks?market=ES
# https://api.spotify.com/v1/artists/60d24wfXkVzDSfLS6hyCjZ/top-tracks?market=ES
# https://api.spotify.com/v1/artists/6lB8vOoI4DRrrVxXwuV19c/top-tracks?market=ES
# https://api.spotify.com/v1/artists/4ehtJnVumNf6xzSCDk8aLB/top-tracks?market=ES
# https://api.spotify.com/v1/artists/6hyMWrxGBsOx6sWcVj1DqP/top-tracks?market=ES
# https://api.spotify.com/v1/artists/5wwneIFdawNgQ7GvKK29Z3/top-tracks?market=ES
# https://api.spotify.com/v1/artists/3tLYpanVDomWAZqF82NPds/top-tracks?market=ES
# https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ/top-tracks?market=ES
# https://api.spotify.com/v1/artists/1l2ekx5skC4gJH8djERwh1/top-tracks?market=ES
# https://api.spotify.com/v1/artists/1bj5GrcLom5gZFF5t949Xl/top-tracks?market=ES
# https://api.spotify.com/v1/artists/77AiFEVeAVj2ORpC85QVJs/top-tracks?market=ES
# https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN/top-tracks?market=ES
# [{'tracks': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#        'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#        'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#        'name': 'David Guetta',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6KV17NyVQwm5PJOVwAVlyV'},
#      'href': 'https://api.spotify.com/v1/albums/6KV17NyVQwm5PJOVwAVlyV',
#      'id': '6KV17NyVQwm5PJOVwAVlyV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27368c13496a915eea4d4325681',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0268c13496a915eea4d4325681',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485168c13496a915eea4d4325681',
#        'width': 64}],
#      'name': 'Hero',
#      'release_date': '2021-04-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6KV17NyVQwm5PJOVwAVlyV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#       'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#       'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#       'name': 'David Guetta',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'}],
#     'disc_number': 1,
#     'duration_ms': 171840,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA222100011'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/29p6UW08MXzwj9thWBW3uF'},
#     'href': 'https://api.spotify.com/v1/tracks/29p6UW08MXzwj9thWBW3uF',
#     'id': '29p6UW08MXzwj9thWBW3uF',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hero',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1a055e1c175cb696e29985e6ec9eb2050c983c0a?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:29p6UW08MXzwj9thWBW3uF'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wwneIFdawNgQ7GvKK29Z3'},
#        'href': 'https://api.spotify.com/v1/artists/5wwneIFdawNgQ7GvKK29Z3',
#        'id': '5wwneIFdawNgQ7GvKK29Z3',
#        'name': 'Lucas & Steve',
#        'type': 'artist',
#        'uri': 'spotify:artist:5wwneIFdawNgQ7GvKK29Z3'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XINWZaloea97SIRiyTJxX'},
#        'href': 'https://api.spotify.com/v1/artists/3XINWZaloea97SIRiyTJxX',
#        'id': '3XINWZaloea97SIRiyTJxX',
#        'name': 'DubVision',
#        'type': 'artist',
#        'uri': 'spotify:artist:3XINWZaloea97SIRiyTJxX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0JaOI27aTExNAnLHpKi2wl'},
#      'href': 'https://api.spotify.com/v1/albums/0JaOI27aTExNAnLHpKi2wl',
#      'id': '0JaOI27aTExNAnLHpKi2wl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273815fb97e1a0010b39d06d28f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02815fb97e1a0010b39d06d28f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851815fb97e1a0010b39d06d28f',
#        'width': 64}],
#      'name': 'Anywhere With You',
#      'release_date': '2021-09-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0JaOI27aTExNAnLHpKi2wl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wwneIFdawNgQ7GvKK29Z3'},
#       'href': 'https://api.spotify.com/v1/artists/5wwneIFdawNgQ7GvKK29Z3',
#       'id': '5wwneIFdawNgQ7GvKK29Z3',
#       'name': 'Lucas & Steve',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wwneIFdawNgQ7GvKK29Z3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XINWZaloea97SIRiyTJxX'},
#       'href': 'https://api.spotify.com/v1/artists/3XINWZaloea97SIRiyTJxX',
#       'id': '3XINWZaloea97SIRiyTJxX',
#       'name': 'DubVision',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XINWZaloea97SIRiyTJxX'}],
#     'disc_number': 1,
#     'duration_ms': 158807,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA222100043'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5MxKAr6Ui5hQ9TtjdnlmrR'},
#     'href': 'https://api.spotify.com/v1/tracks/5MxKAr6Ui5hQ9TtjdnlmrR',
#     'id': '5MxKAr6Ui5hQ9TtjdnlmrR',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Anywhere With You',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/946544a1440b2ab59157bb34bb770a431ce28e59?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5MxKAr6Ui5hQ9TtjdnlmrR'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4mrBetqy378Jf1y6NLszlx'},
#        'href': 'https://api.spotify.com/v1/artists/4mrBetqy378Jf1y6NLszlx',
#        'id': '4mrBetqy378Jf1y6NLszlx',
#        'name': 'VINAI',
#        'type': 'artist',
#        'uri': 'spotify:artist:4mrBetqy378Jf1y6NLszlx'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tLvKk2N4IGhT3aZceW2Hy'},
#        'href': 'https://api.spotify.com/v1/artists/3tLvKk2N4IGhT3aZceW2Hy',
#        'id': '3tLvKk2N4IGhT3aZceW2Hy',
#        'name': 'Hard Lights',
#        'type': 'artist',
#        'uri': 'spotify:artist:3tLvKk2N4IGhT3aZceW2Hy'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4VaU66GBM1rn0YXsZIkHbJ'},
#      'href': 'https://api.spotify.com/v1/albums/4VaU66GBM1rn0YXsZIkHbJ',
#      'id': '4VaU66GBM1rn0YXsZIkHbJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273848b73a862107e28cbc64ebd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02848b73a862107e28cbc64ebd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851848b73a862107e28cbc64ebd',
#        'width': 64}],
#      'name': 'Up All Night (feat. Afrojack)',
#      'release_date': '2020-10-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4VaU66GBM1rn0YXsZIkHbJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4mrBetqy378Jf1y6NLszlx'},
#       'href': 'https://api.spotify.com/v1/artists/4mrBetqy378Jf1y6NLszlx',
#       'id': '4mrBetqy378Jf1y6NLszlx',
#       'name': 'VINAI',
#       'type': 'artist',
#       'uri': 'spotify:artist:4mrBetqy378Jf1y6NLszlx'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tLvKk2N4IGhT3aZceW2Hy'},
#       'href': 'https://api.spotify.com/v1/artists/3tLvKk2N4IGhT3aZceW2Hy',
#       'id': '3tLvKk2N4IGhT3aZceW2Hy',
#       'name': 'Hard Lights',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tLvKk2N4IGhT3aZceW2Hy'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#     'disc_number': 1,
#     'duration_ms': 160906,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR9W12022698'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5k1uIPpsHmnbWFr4nbpdYb'},
#     'href': 'https://api.spotify.com/v1/tracks/5k1uIPpsHmnbWFr4nbpdYb',
#     'id': '5k1uIPpsHmnbWFr4nbpdYb',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Up All Night (feat. Afrojack)',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4771a10f6aaf06ee3534d18765b1acf5f05c6c7?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5k1uIPpsHmnbWFr4nbpdYb'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5OdVywqKqyCWwfE2fZb7IX'},
#        'href': 'https://api.spotify.com/v1/artists/5OdVywqKqyCWwfE2fZb7IX',
#        'id': '5OdVywqKqyCWwfE2fZb7IX',
#        'name': 'Chico Rose',
#        'type': 'artist',
#        'uri': 'spotify:artist:5OdVywqKqyCWwfE2fZb7IX'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3iyLP2ce8hthgd4ygzLRJD'},
#      'href': 'https://api.spotify.com/v1/albums/3iyLP2ce8hthgd4ygzLRJD',
#      'id': '3iyLP2ce8hthgd4ygzLRJD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273383e3a4822a5fda0267d19c4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02383e3a4822a5fda0267d19c4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851383e3a4822a5fda0267d19c4',
#        'width': 64}],
#      'name': 'Sad (feat. Afrojack)',
#      'release_date': '2019-08-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3iyLP2ce8hthgd4ygzLRJD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5OdVywqKqyCWwfE2fZb7IX'},
#       'href': 'https://api.spotify.com/v1/artists/5OdVywqKqyCWwfE2fZb7IX',
#       'id': '5OdVywqKqyCWwfE2fZb7IX',
#       'name': 'Chico Rose',
#       'type': 'artist',
#       'uri': 'spotify:artist:5OdVywqKqyCWwfE2fZb7IX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#     'disc_number': 1,
#     'duration_ms': 161280,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLZ541901236'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ESPuOrSsRcBISzcMlzmY5'},
#     'href': 'https://api.spotify.com/v1/tracks/4ESPuOrSsRcBISzcMlzmY5',
#     'id': '4ESPuOrSsRcBISzcMlzmY5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sad (feat. Afrojack)',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0662422298035259dfbbaf11957591bad8a4a3bb?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4ESPuOrSsRcBISzcMlzmY5'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CbeG1224FS58EUx4tPevZ'},
#        'href': 'https://api.spotify.com/v1/artists/0CbeG1224FS58EUx4tPevZ',
#        'id': '0CbeG1224FS58EUx4tPevZ',
#        'name': 'Timmy Trumpet',
#        'type': 'artist',
#        'uri': 'spotify:artist:0CbeG1224FS58EUx4tPevZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/15v2LmWavzASn38XSzS0dO'},
#      'href': 'https://api.spotify.com/v1/albums/15v2LmWavzASn38XSzS0dO',
#      'id': '15v2LmWavzASn38XSzS0dO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730ba36962a0a6e92ff8d6399e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020ba36962a0a6e92ff8d6399e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510ba36962a0a6e92ff8d6399e',
#        'width': 64}],
#      'name': 'Stay Mine',
#      'release_date': '2021-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:15v2LmWavzASn38XSzS0dO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CbeG1224FS58EUx4tPevZ'},
#       'href': 'https://api.spotify.com/v1/artists/0CbeG1224FS58EUx4tPevZ',
#       'id': '0CbeG1224FS58EUx4tPevZ',
#       'name': 'Timmy Trumpet',
#       'type': 'artist',
#       'uri': 'spotify:artist:0CbeG1224FS58EUx4tPevZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#     'disc_number': 1,
#     'duration_ms': 178010,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLZ542100432'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IhWJM8cN04zRQ2PNM91xc'},
#     'href': 'https://api.spotify.com/v1/tracks/7IhWJM8cN04zRQ2PNM91xc',
#     'id': '7IhWJM8cN04zRQ2PNM91xc',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Stay Mine',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2d13ce07f65569df234225a589617791a441b1c3?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7IhWJM8cN04zRQ2PNM91xc'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7G1441qDQeERZDyMipQPE8'},
#      'href': 'https://api.spotify.com/v1/albums/7G1441qDQeERZDyMipQPE8',
#      'id': '7G1441qDQeERZDyMipQPE8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b3d1511a14dbfb2ba74bdf18',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b3d1511a14dbfb2ba74bdf18',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b3d1511a14dbfb2ba74bdf18',
#        'width': 64}],
#      'name': 'Forget The World (Deluxe)',
#      'release_date': '2014-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:7G1441qDQeERZDyMipQPE8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7r2uG6BlFXKcwmh9ItqlII'},
#       'href': 'https://api.spotify.com/v1/artists/7r2uG6BlFXKcwmh9ItqlII',
#       'id': '7r2uG6BlFXKcwmh9ItqlII',
#       'name': 'Wrabel',
#       'type': 'artist',
#       'uri': 'spotify:artist:7r2uG6BlFXKcwmh9ItqlII'}],
#     'disc_number': 1,
#     'duration_ms': 229149,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA221400001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ldAdghnrO34HPcZ0IWfTu'},
#     'href': 'https://api.spotify.com/v1/tracks/2ldAdghnrO34HPcZ0IWfTu',
#     'id': '2ldAdghnrO34HPcZ0IWfTu',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Ten Feet Tall',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2ldAdghnrO34HPcZ0IWfTu'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rGrDvrLOV2VV8SCFVGWlj'},
#        'href': 'https://api.spotify.com/v1/artists/5rGrDvrLOV2VV8SCFVGWlj',
#        'id': '5rGrDvrLOV2VV8SCFVGWlj',
#        'name': 'Imanbek',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rGrDvrLOV2VV8SCFVGWlj'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/71WExccCBN2mw0klSzfYzz'},
#        'href': 'https://api.spotify.com/v1/artists/71WExccCBN2mw0klSzfYzz',
#        'id': '71WExccCBN2mw0klSzfYzz',
#        'name': 'Gia Koka',
#        'type': 'artist',
#        'uri': 'spotify:artist:71WExccCBN2mw0klSzfYzz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0wMS7Uv7zvR9e7xCTqo39u'},
#      'href': 'https://api.spotify.com/v1/albums/0wMS7Uv7zvR9e7xCTqo39u',
#      'id': '0wMS7Uv7zvR9e7xCTqo39u',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27337dc0a395d512a2ccc7e36c9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0237dc0a395d512a2ccc7e36c9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485137dc0a395d512a2ccc7e36c9',
#        'width': 64}],
#      'name': 'Hey Baby (feat. Gia Koka)',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0wMS7Uv7zvR9e7xCTqo39u'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rGrDvrLOV2VV8SCFVGWlj'},
#       'href': 'https://api.spotify.com/v1/artists/5rGrDvrLOV2VV8SCFVGWlj',
#       'id': '5rGrDvrLOV2VV8SCFVGWlj',
#       'name': 'Imanbek',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rGrDvrLOV2VV8SCFVGWlj'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/71WExccCBN2mw0klSzfYzz'},
#       'href': 'https://api.spotify.com/v1/artists/71WExccCBN2mw0klSzfYzz',
#       'id': '71WExccCBN2mw0klSzfYzz',
#       'name': 'Gia Koka',
#       'type': 'artist',
#       'uri': 'spotify:artist:71WExccCBN2mw0klSzfYzz'}],
#     'disc_number': 1,
#     'duration_ms': 177545,
#     'explicit': False,
#     'external_ids': {'isrc': 'DK4YA2090001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3bNIlJBpwgwFNnFuSjH6Uh'},
#     'href': 'https://api.spotify.com/v1/tracks/3bNIlJBpwgwFNnFuSjH6Uh',
#     'id': '3bNIlJBpwgwFNnFuSjH6Uh',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hey Baby (feat. Gia Koka)',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6a60128c5f6e480affc9fe0acef409c8760b7d78?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3bNIlJBpwgwFNnFuSjH6Uh'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47BEc2RoW53owMyxacXWdV'},
#        'href': 'https://api.spotify.com/v1/artists/47BEc2RoW53owMyxacXWdV',
#        'id': '47BEc2RoW53owMyxacXWdV',
#        'name': 'Yves V',
#        'type': 'artist',
#        'uri': 'spotify:artist:47BEc2RoW53owMyxacXWdV'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1VBflYyxBhnDc9uVib98rw'},
#        'href': 'https://api.spotify.com/v1/artists/1VBflYyxBhnDc9uVib98rw',
#        'id': '1VBflYyxBhnDc9uVib98rw',
#        'name': 'Icona Pop',
#        'type': 'artist',
#        'uri': 'spotify:artist:1VBflYyxBhnDc9uVib98rw'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1WowOfXnw3DlwgjyzlAU4Q'},
#      'href': 'https://api.spotify.com/v1/albums/1WowOfXnw3DlwgjyzlAU4Q',
#      'id': '1WowOfXnw3DlwgjyzlAU4Q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273261381ee47543f6faddb10bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02261381ee47543f6faddb10bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851261381ee47543f6faddb10bf',
#        'width': 64}],
#      'name': 'We Got That Cool (feat. Afrojack & Icona Pop)',
#      'release_date': '2019-06-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1WowOfXnw3DlwgjyzlAU4Q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47BEc2RoW53owMyxacXWdV'},
#       'href': 'https://api.spotify.com/v1/artists/47BEc2RoW53owMyxacXWdV',
#       'id': '47BEc2RoW53owMyxacXWdV',
#       'name': 'Yves V',
#       'type': 'artist',
#       'uri': 'spotify:artist:47BEc2RoW53owMyxacXWdV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1VBflYyxBhnDc9uVib98rw'},
#       'href': 'https://api.spotify.com/v1/artists/1VBflYyxBhnDc9uVib98rw',
#       'id': '1VBflYyxBhnDc9uVib98rw',
#       'name': 'Icona Pop',
#       'type': 'artist',
#       'uri': 'spotify:artist:1VBflYyxBhnDc9uVib98rw'}],
#     'disc_number': 1,
#     'duration_ms': 213000,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLZ541900844'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2cFK03sObtI6AK3QKeOT5g'},
#     'href': 'https://api.spotify.com/v1/tracks/2cFK03sObtI6AK3QKeOT5g',
#     'id': '2cFK03sObtI6AK3QKeOT5g',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'We Got That Cool (feat. Afrojack & Icona Pop)',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0dcb6c9e6f1c533bf57a0e9a21400bf2bf814269?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2cFK03sObtI6AK3QKeOT5g'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3DJVDo0kd19fZXpTabasOX'},
#        'href': 'https://api.spotify.com/v1/artists/3DJVDo0kd19fZXpTabasOX',
#        'id': '3DJVDo0kd19fZXpTabasOX',
#        'name': 'Zafrir',
#        'type': 'artist',
#        'uri': 'spotify:artist:3DJVDo0kd19fZXpTabasOX'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UTRfRr2s6XLj3It38Vw8d'},
#      'href': 'https://api.spotify.com/v1/albums/3UTRfRr2s6XLj3It38Vw8d',
#      'id': '3UTRfRr2s6XLj3It38Vw8d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d95a69b6ed77cb639d819064',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d95a69b6ed77cb639d819064',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d95a69b6ed77cb639d819064',
#        'width': 64}],
#      'name': 'Boom Boom Pow',
#      'release_date': '2021-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3UTRfRr2s6XLj3It38Vw8d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3DJVDo0kd19fZXpTabasOX'},
#       'href': 'https://api.spotify.com/v1/artists/3DJVDo0kd19fZXpTabasOX',
#       'id': '3DJVDo0kd19fZXpTabasOX',
#       'name': 'Zafrir',
#       'type': 'artist',
#       'uri': 'spotify:artist:3DJVDo0kd19fZXpTabasOX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#     'disc_number': 1,
#     'duration_ms': 185413,
#     'explicit': True,
#     'external_ids': {'isrc': 'FR9W12104228'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4S2qrsdY4BF0T5UFQLtqoU'},
#     'href': 'https://api.spotify.com/v1/tracks/4S2qrsdY4BF0T5UFQLtqoU',
#     'id': '4S2qrsdY4BF0T5UFQLtqoU',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Boom Boom Pow',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/744a94f3d7a78f980533bd7330f455e117e49b09?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4S2qrsdY4BF0T5UFQLtqoU'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7BUaQCq7sFUMJqkWPqApXE'},
#        'href': 'https://api.spotify.com/v1/artists/7BUaQCq7sFUMJqkWPqApXE',
#        'id': '7BUaQCq7sFUMJqkWPqApXE',
#        'name': 'Never Sleeps',
#        'type': 'artist',
#        'uri': 'spotify:artist:7BUaQCq7sFUMJqkWPqApXE'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#        'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#        'id': '4D75GcNG95ebPtNvoNVXhz',
#        'name': 'Afrojack',
#        'type': 'artist',
#        'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5OdVywqKqyCWwfE2fZb7IX'},
#        'href': 'https://api.spotify.com/v1/artists/5OdVywqKqyCWwfE2fZb7IX',
#        'id': '5OdVywqKqyCWwfE2fZb7IX',
#        'name': 'Chico Rose',
#        'type': 'artist',
#        'uri': 'spotify:artist:5OdVywqKqyCWwfE2fZb7IX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2kNfpqN1fT9lRc1cYuAhWt'},
#      'href': 'https://api.spotify.com/v1/albums/2kNfpqN1fT9lRc1cYuAhWt',
#      'id': '2kNfpqN1fT9lRc1cYuAhWt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27397d993b68fb693379819378a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0297d993b68fb693379819378a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485197d993b68fb693379819378a',
#        'width': 64}],
#      'name': 'You Got The Love',
#      'release_date': '2021-08-27',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:2kNfpqN1fT9lRc1cYuAhWt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7BUaQCq7sFUMJqkWPqApXE'},
#       'href': 'https://api.spotify.com/v1/artists/7BUaQCq7sFUMJqkWPqApXE',
#       'id': '7BUaQCq7sFUMJqkWPqApXE',
#       'name': 'Never Sleeps',
#       'type': 'artist',
#       'uri': 'spotify:artist:7BUaQCq7sFUMJqkWPqApXE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5OdVywqKqyCWwfE2fZb7IX'},
#       'href': 'https://api.spotify.com/v1/artists/5OdVywqKqyCWwfE2fZb7IX',
#       'id': '5OdVywqKqyCWwfE2fZb7IX',
#       'name': 'Chico Rose',
#       'type': 'artist',
#       'uri': 'spotify:artist:5OdVywqKqyCWwfE2fZb7IX'}],
#     'disc_number': 1,
#     'duration_ms': 196684,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA222100030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1O3Jlr6ksM6meUe1atDAxY'},
#     'href': 'https://api.spotify.com/v1/tracks/1O3Jlr6ksM6meUe1atDAxY',
#     'id': '1O3Jlr6ksM6meUe1atDAxY',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'You Got The Love',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1O3Jlr6ksM6meUe1atDAxY'}]},
#  {'tracks': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5p7f24Rk5HkUZsaS3BLG5F'},
#        'href': 'https://api.spotify.com/v1/artists/5p7f24Rk5HkUZsaS3BLG5F',
#        'id': '5p7f24Rk5HkUZsaS3BLG5F',
#        'name': 'Hailee Steinfeld',
#        'type': 'artist',
#        'uri': 'spotify:artist:5p7f24Rk5HkUZsaS3BLG5F'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#        'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#        'id': '4AVFqumd2ogHFlRbKIjp1t',
#        'name': 'Alesso',
#        'type': 'artist',
#        'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3ggBBGRhkDVAu7pQRXRPXO'},
#      'href': 'https://api.spotify.com/v1/albums/3ggBBGRhkDVAu7pQRXRPXO',
#      'id': '3ggBBGRhkDVAu7pQRXRPXO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273523eb48df1fa22b6d450833e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02523eb48df1fa22b6d450833e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851523eb48df1fa22b6d450833e',
#        'width': 64}],
#      'name': 'Let Me Go (with Alesso, Florida Georgia Line & watt)',
#      'release_date': '2017-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3ggBBGRhkDVAu7pQRXRPXO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5p7f24Rk5HkUZsaS3BLG5F'},
#       'href': 'https://api.spotify.com/v1/artists/5p7f24Rk5HkUZsaS3BLG5F',
#       'id': '5p7f24Rk5HkUZsaS3BLG5F',
#       'name': 'Hailee Steinfeld',
#       'type': 'artist',
#       'uri': 'spotify:artist:5p7f24Rk5HkUZsaS3BLG5F'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#       'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#       'id': '4AVFqumd2ogHFlRbKIjp1t',
#       'name': 'Alesso',
#       'type': 'artist',
#       'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3b8QkneNDz4JHKKKlLgYZg'},
#       'href': 'https://api.spotify.com/v1/artists/3b8QkneNDz4JHKKKlLgYZg',
#       'id': '3b8QkneNDz4JHKKKlLgYZg',
#       'name': 'Florida Georgia Line',
#       'type': 'artist',
#       'uri': 'spotify:artist:3b8QkneNDz4JHKKKlLgYZg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4olE3I5QU0dvSR7LIpqTXc'},
#       'href': 'https://api.spotify.com/v1/artists/4olE3I5QU0dvSR7LIpqTXc',
#       'id': '4olE3I5QU0dvSR7LIpqTXc',
#       'name': 'WATT',
#       'type': 'artist',
#       'uri': 'spotify:artist:4olE3I5QU0dvSR7LIpqTXc'}],
#     'disc_number': 1,
#     'duration_ms': 174800,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71709685'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Gu0PDLN4YJeW75PpBSg9p'},
#     'href': 'https://api.spotify.com/v1/tracks/5Gu0PDLN4YJeW75PpBSg9p',
#     'id': '5Gu0PDLN4YJeW75PpBSg9p',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Let Me Go (with Alesso, Florida Georgia Line & watt)',
#     'popularity': 79,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Gu0PDLN4YJeW75PpBSg9p'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#        'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#        'id': '4AVFqumd2ogHFlRbKIjp1t',
#        'name': 'Alesso',
#        'type': 'artist',
#        'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#        'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#        'id': '64KEffDW9EtZ1y2vBYgq8T',
#        'name': 'Marshmello',
#        'type': 'artist',
#        'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4EzkuveR9pLvDVFNx6foYD'},
#        'href': 'https://api.spotify.com/v1/artists/4EzkuveR9pLvDVFNx6foYD',
#        'id': '4EzkuveR9pLvDVFNx6foYD',
#        'name': 'James Bay',
#        'type': 'artist',
#        'uri': 'spotify:artist:4EzkuveR9pLvDVFNx6foYD'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/09vWMvGsbMxlVuFS7hCsf6'},
#      'href': 'https://api.spotify.com/v1/albums/09vWMvGsbMxlVuFS7hCsf6',
#      'id': '09vWMvGsbMxlVuFS7hCsf6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739489ebf0074a28c554637780',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029489ebf0074a28c554637780',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519489ebf0074a28c554637780',
#        'width': 64}],
#      'name': 'Chasing Stars (feat. James Bay)',
#      'release_date': '2021-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:09vWMvGsbMxlVuFS7hCsf6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#       'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#       'id': '4AVFqumd2ogHFlRbKIjp1t',
#       'name': 'Alesso',
#       'type': 'artist',
#       'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#       'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#       'id': '64KEffDW9EtZ1y2vBYgq8T',
#       'name': 'Marshmello',
#       'type': 'artist',
#       'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4EzkuveR9pLvDVFNx6foYD'},
#       'href': 'https://api.spotify.com/v1/artists/4EzkuveR9pLvDVFNx6foYD',
#       'id': '4EzkuveR9pLvDVFNx6foYD',
#       'name': 'James Bay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EzkuveR9pLvDVFNx6foYD'}],
#     'disc_number': 1,
#     'duration_ms': 170457,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12103606'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6y6xhAgZjvxy5kR5rigpY3'},
#     'href': 'https://api.spotify.com/v1/tracks/6y6xhAgZjvxy5kR5rigpY3',
#     'id': '6y6xhAgZjvxy5kR5rigpY3',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Chasing Stars (feat. James Bay)',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6y6xhAgZjvxy5kR5rigpY3'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#        'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#        'id': '4AVFqumd2ogHFlRbKIjp1t',
#        'name': 'Alesso',
#        'type': 'artist',
#        'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5pUo3fmmHT8bhCyHE52hA6'},
#        'href': 'https://api.spotify.com/v1/artists/5pUo3fmmHT8bhCyHE52hA6',
#        'id': '5pUo3fmmHT8bhCyHE52hA6',
#        'name': 'Liam Payne',
#        'type': 'artist',
#        'uri': 'spotify:artist:5pUo3fmmHT8bhCyHE52hA6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Cq0dfyCX1msQ6ZRbdT4YG'},
#      'href': 'https://api.spotify.com/v1/albums/4Cq0dfyCX1msQ6ZRbdT4YG',
#      'id': '4Cq0dfyCX1msQ6ZRbdT4YG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273107d930ebe7cba0ff31c605c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02107d930ebe7cba0ff31c605c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851107d930ebe7cba0ff31c605c',
#        'width': 64}],
#      'name': 'Midnight (feat. Liam Payne)',
#      'release_date': '2020-04-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4Cq0dfyCX1msQ6ZRbdT4YG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#       'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#       'id': '4AVFqumd2ogHFlRbKIjp1t',
#       'name': 'Alesso',
#       'type': 'artist',
#       'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5pUo3fmmHT8bhCyHE52hA6'},
#       'href': 'https://api.spotify.com/v1/artists/5pUo3fmmHT8bhCyHE52hA6',
#       'id': '5pUo3fmmHT8bhCyHE52hA6',
#       'name': 'Liam Payne',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pUo3fmmHT8bhCyHE52hA6'}],
#     'disc_number': 1,
#     'duration_ms': 220140,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12000913'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ZTTUAjJCd4NMZmIU7RB4c'},
#     'href': 'https://api.spotify.com/v1/tracks/4ZTTUAjJCd4NMZmIU7RB4c',
#     'id': '4ZTTUAjJCd4NMZmIU7RB4c',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Midnight (feat. Liam Payne)',
#     'popularity': 74,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4ZTTUAjJCd4NMZmIU7RB4c'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#        'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#        'id': '7CajNmpbOovFoOoasH2HaY',
#        'name': 'Calvin Harris',
#        'type': 'artist',
#        'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/48zisMeiXniWLzOQghbPqS'},
#      'href': 'https://api.spotify.com/v1/albums/48zisMeiXniWLzOQghbPqS',
#      'id': '48zisMeiXniWLzOQghbPqS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273063c048e9ef6bd021b744756',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02063c048e9ef6bd021b744756',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851063c048e9ef6bd021b744756',
#        'width': 64}],
#      'name': 'Motion',
#      'release_date': '2014-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:48zisMeiXniWLzOQghbPqS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#       'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#       'id': '7CajNmpbOovFoOoasH2HaY',
#       'name': 'Calvin Harris',
#       'type': 'artist',
#       'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#       'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#       'id': '4AVFqumd2ogHFlRbKIjp1t',
#       'name': 'Alesso',
#       'type': 'artist',
#       'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3w4VAlllkAWI6m0AV0Gn6a'},
#       'href': 'https://api.spotify.com/v1/artists/3w4VAlllkAWI6m0AV0Gn6a',
#       'id': '3w4VAlllkAWI6m0AV0Gn6a',
#       'name': 'Hurts',
#       'type': 'artist',
#       'uri': 'spotify:artist:3w4VAlllkAWI6m0AV0Gn6a'}],
#     'disc_number': 1,
#     'duration_ms': 184280,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBARL1301271'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4J7CKHCF3mdL4diUsmW8lq'},
#     'href': 'https://api.spotify.com/v1/tracks/4J7CKHCF3mdL4diUsmW8lq',
#     'id': '4J7CKHCF3mdL4diUsmW8lq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Under Control (feat. Hurts)',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7a839c5734d94a0fb9d343aa8c88255d9e9605eb?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4J7CKHCF3mdL4diUsmW8lq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#        'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#        'id': '4AVFqumd2ogHFlRbKIjp1t',
#        'name': 'Alesso',
#        'type': 'artist',
#        'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0tRVSbmOwilUucqjzU0fQw'},
#      'href': 'https://api.spotify.com/v1/albums/0tRVSbmOwilUucqjzU0fQw',
#      'id': '0tRVSbmOwilUucqjzU0fQw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b804bbd11f864902d452b3a7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b804bbd11f864902d452b3a7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b804bbd11f864902d452b3a7',
#        'width': 64}],
#      'name': 'Forever',
#      'release_date': '2015-05-26',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0tRVSbmOwilUucqjzU0fQw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#       'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#       'id': '4AVFqumd2ogHFlRbKIjp1t',
#       'name': 'Alesso',
#       'type': 'artist',
#       'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NHQUGzhtTLFvgF5SZesLK'},
#       'href': 'https://api.spotify.com/v1/artists/4NHQUGzhtTLFvgF5SZesLK',
#       'id': '4NHQUGzhtTLFvgF5SZesLK',
#       'name': 'Tove Lo',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NHQUGzhtTLFvgF5SZesLK'}],
#     'disc_number': 1,
#     'duration_ms': 210013,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71411636'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3zU9rdflI65tK4dkkNSp77'},
#     'href': 'https://api.spotify.com/v1/tracks/3zU9rdflI65tK4dkkNSp77',
#     'id': '3zU9rdflI65tK4dkkNSp77',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Heroes (we could be)',
#     'popularity': 73,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3zU9rdflI65tK4dkkNSp77'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#        'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#        'id': '4AVFqumd2ogHFlRbKIjp1t',
#        'name': 'Alesso',
#        'type': 'artist',
#        'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1TcbdifqhtxLz77unBYJ7z'},
#        'href': 'https://api.spotify.com/v1/artists/1TcbdifqhtxLz77unBYJ7z',
#        'id': '1TcbdifqhtxLz77unBYJ7z',
#        'name': 'CORSAK',
#        'type': 'artist',
#        'uri': 'spotify:artist:1TcbdifqhtxLz77unBYJ7z'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2dIgFjalVxs4ThymZ67YCE'},
#        'href': 'https://api.spotify.com/v1/artists/2dIgFjalVxs4ThymZ67YCE',
#        'id': '2dIgFjalVxs4ThymZ67YCE',
#        'name': 'Stray Kids',
#        'type': 'artist',
#        'uri': 'spotify:artist:2dIgFjalVxs4ThymZ67YCE'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5IMZvYqklgYzabWtgtD74l'},
#      'href': 'https://api.spotify.com/v1/albums/5IMZvYqklgYzabWtgtD74l',
#      'id': '5IMZvYqklgYzabWtgtD74l',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27379e0572c54f0afba2187c671',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0279e0572c54f0afba2187c671',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485179e0572c54f0afba2187c671',
#        'width': 64}],
# ...
#     'popularity': 59,
#     'preview_url': None,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:4ksheDQWyWfjG5ETO0aokW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#        'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#        'id': '1IueXOQyABrMOprrzwQJWN',
#        'name': 'Sigala',
#        'type': 'artist',
#        'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5rr0xAQfk01cPi1N37jX11'},
#      'href': 'https://api.spotify.com/v1/albums/5rr0xAQfk01cPi1N37jX11',
#      'id': '5rr0xAQfk01cPi1N37jX11',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273681d6da9a0ab5ff23fadf0f9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02681d6da9a0ab5ff23fadf0f9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851681d6da9a0ab5ff23fadf0f9',
#        'width': 64}],
#      'name': 'Brighter Days',
#      'release_date': '2018-09-28',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5rr0xAQfk01cPi1N37jX11'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#     'disc_number': 1,
#     'duration_ms': 229813,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEN1500481'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5s7xgzXtmY4gMjeSlgisjy'},
#     'href': 'https://api.spotify.com/v1/tracks/5s7xgzXtmY4gMjeSlgisjy',
#     'id': '5s7xgzXtmY4gMjeSlgisjy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Easy Love',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6d19019e3cf1fc3e8cf5ecc86029020d51151c7e?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:5s7xgzXtmY4gMjeSlgisjy'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#        'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#        'id': '1IueXOQyABrMOprrzwQJWN',
#        'name': 'Sigala',
#        'type': 'artist',
#        'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nDsS0l5ZAzMedVRKPP8F1'},
#        'href': 'https://api.spotify.com/v1/artists/7nDsS0l5ZAzMedVRKPP8F1',
#        'id': '7nDsS0l5ZAzMedVRKPP8F1',
#        'name': 'Ella Henderson',
#        'type': 'artist',
#        'uri': 'spotify:artist:7nDsS0l5ZAzMedVRKPP8F1'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4GtslEn7rHERVWRlqrYehy'},
#      'href': 'https://api.spotify.com/v1/albums/4GtslEn7rHERVWRlqrYehy',
#      'id': '4GtslEn7rHERVWRlqrYehy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273002753665f089902cc74cbe6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02002753665f089902cc74cbe6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851002753665f089902cc74cbe6',
#        'width': 64}],
#      'name': 'We Got Love',
#      'release_date': '2019-11-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4GtslEn7rHERVWRlqrYehy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nDsS0l5ZAzMedVRKPP8F1'},
#       'href': 'https://api.spotify.com/v1/artists/7nDsS0l5ZAzMedVRKPP8F1',
#       'id': '7nDsS0l5ZAzMedVRKPP8F1',
#       'name': 'Ella Henderson',
#       'type': 'artist',
#       'uri': 'spotify:artist:7nDsS0l5ZAzMedVRKPP8F1'}],
#     'disc_number': 1,
#     'duration_ms': 213040,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEN1900077'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/35mMXfym6C9VOTUVrcKKZp'},
#     'href': 'https://api.spotify.com/v1/tracks/35mMXfym6C9VOTUVrcKKZp',
#     'id': '35mMXfym6C9VOTUVrcKKZp',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'We Got Love',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8b80c3a06c8e4376e90dc69622008210f040c907?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:35mMXfym6C9VOTUVrcKKZp'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#        'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#        'id': '1IueXOQyABrMOprrzwQJWN',
#        'name': 'Sigala',
#        'type': 'artist',
#        'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4EPJlUEBy49EX1wuFOvtjK'},
#        'href': 'https://api.spotify.com/v1/artists/4EPJlUEBy49EX1wuFOvtjK',
#        'id': '4EPJlUEBy49EX1wuFOvtjK',
#        'name': 'Becky Hill',
#        'type': 'artist',
#        'uri': 'spotify:artist:4EPJlUEBy49EX1wuFOvtjK'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1yZZdubJ2rovC4QIBP8riQ'},
#      'href': 'https://api.spotify.com/v1/albums/1yZZdubJ2rovC4QIBP8riQ',
#      'id': '1yZZdubJ2rovC4QIBP8riQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27317ee64e0de457686c3c247cd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0217ee64e0de457686c3c247cd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485117ee64e0de457686c3c247cd',
#        'width': 64}],
#      'name': 'Wish You Well',
#      'release_date': '2019-05-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1yZZdubJ2rovC4QIBP8riQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4EPJlUEBy49EX1wuFOvtjK'},
#       'href': 'https://api.spotify.com/v1/artists/4EPJlUEBy49EX1wuFOvtjK',
#       'id': '4EPJlUEBy49EX1wuFOvtjK',
#       'name': 'Becky Hill',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EPJlUEBy49EX1wuFOvtjK'}],
#     'disc_number': 1,
#     'duration_ms': 205653,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEN1900019'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1yAPglN5AGf7UoLK062ZYq'},
#     'href': 'https://api.spotify.com/v1/tracks/1yAPglN5AGf7UoLK062ZYq',
#     'id': '1yAPglN5AGf7UoLK062ZYq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Wish You Well',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/56962f8e1d8b7ade550d80701b2eeea60b88e370?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1yAPglN5AGf7UoLK062ZYq'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#        'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#        'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#        'name': 'R3HAB',
#        'type': 'artist',
#        'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#        'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#        'id': '1IueXOQyABrMOprrzwQJWN',
#        'name': 'Sigala',
#        'type': 'artist',
#        'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYGAK2zu9EAomwj3hXkXy'},
#        'href': 'https://api.spotify.com/v1/artists/4kYGAK2zu9EAomwj3hXkXy',
#        'id': '4kYGAK2zu9EAomwj3hXkXy',
#        'name': 'JP Cooper',
#        'type': 'artist',
#        'uri': 'spotify:artist:4kYGAK2zu9EAomwj3hXkXy'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0HarHaqweXXH7ddIY6EX77'},
#      'href': 'https://api.spotify.com/v1/albums/0HarHaqweXXH7ddIY6EX77',
#      'id': '0HarHaqweXXH7ddIY6EX77',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27353a2dce47d2089a9e567436d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0253a2dce47d2089a9e567436d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485153a2dce47d2089a9e567436d',
#        'width': 64}],
#      'name': 'Runaway (with Sigala & JP Cooper)',
#      'release_date': '2021-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0HarHaqweXXH7ddIY6EX77'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#       'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#       'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#       'name': 'R3HAB',
#       'type': 'artist',
#       'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYGAK2zu9EAomwj3hXkXy'},
#       'href': 'https://api.spotify.com/v1/artists/4kYGAK2zu9EAomwj3hXkXy',
#       'id': '4kYGAK2zu9EAomwj3hXkXy',
#       'name': 'JP Cooper',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYGAK2zu9EAomwj3hXkXy'}],
#     'disc_number': 1,
#     'duration_ms': 168196,
#     'explicit': False,
#     'external_ids': {'isrc': 'AEA2D2100063'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5H8fYiRySoxCnsjVzV67HO'},
#     'href': 'https://api.spotify.com/v1/tracks/5H8fYiRySoxCnsjVzV67HO',
#     'id': '5H8fYiRySoxCnsjVzV67HO',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Runaway (with Sigala & JP Cooper)',
#     'popularity': 67,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5H8fYiRySoxCnsjVzV67HO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#        'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#        'id': '1IueXOQyABrMOprrzwQJWN',
#        'name': 'Sigala',
#        'type': 'artist',
#        'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5rr0xAQfk01cPi1N37jX11'},
#      'href': 'https://api.spotify.com/v1/albums/5rr0xAQfk01cPi1N37jX11',
#      'id': '5rr0xAQfk01cPi1N37jX11',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273681d6da9a0ab5ff23fadf0f9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02681d6da9a0ab5ff23fadf0f9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851681d6da9a0ab5ff23fadf0f9',
#        'width': 64}],
#      'name': 'Brighter Days',
#      'release_date': '2018-09-28',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5rr0xAQfk01cPi1N37jX11'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/66TrUkUZ3RM29dqeDQRgyA'},
#       'href': 'https://api.spotify.com/v1/artists/66TrUkUZ3RM29dqeDQRgyA',
#       'id': '66TrUkUZ3RM29dqeDQRgyA',
#       'name': 'Ella Eyre',
#       'type': 'artist',
#       'uri': 'spotify:artist:66TrUkUZ3RM29dqeDQRgyA'}],
#     'disc_number': 1,
#     'duration_ms': 203386,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEN1700157'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0mGJTKRIuCOJtiT4YkJHiv'},
#     'href': 'https://api.spotify.com/v1/tracks/0mGJTKRIuCOJtiT4YkJHiv',
#     'id': '0mGJTKRIuCOJtiT4YkJHiv',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Came Here for Love',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2d88d0999e45021573b20f7bafa5afcf6210b1cb?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0mGJTKRIuCOJtiT4YkJHiv'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#        'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#        'id': '1IueXOQyABrMOprrzwQJWN',
#        'name': 'Sigala',
#        'type': 'artist',
#        'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5rr0xAQfk01cPi1N37jX11'},
#      'href': 'https://api.spotify.com/v1/albums/5rr0xAQfk01cPi1N37jX11',
#      'id': '5rr0xAQfk01cPi1N37jX11',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273681d6da9a0ab5ff23fadf0f9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02681d6da9a0ab5ff23fadf0f9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851681d6da9a0ab5ff23fadf0f9',
#        'width': 64}],
#      'name': 'Brighter Days',
#      'release_date': '2018-09-28',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5rr0xAQfk01cPi1N37jX11'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7mWMzxN6IAIQ1tfFFtAiQv'},
#       'href': 'https://api.spotify.com/v1/artists/7mWMzxN6IAIQ1tfFFtAiQv',
#       'id': '7mWMzxN6IAIQ1tfFFtAiQv',
#       'name': 'Bryn Christopher',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mWMzxN6IAIQ1tfFFtAiQv'}],
#     'disc_number': 1,
#     'duration_ms': 202213,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEN1501213'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1qp0ptMXNg9hqLH8sk7cc2'},
#     'href': 'https://api.spotify.com/v1/tracks/1qp0ptMXNg9hqLH8sk7cc2',
#     'id': '1qp0ptMXNg9hqLH8sk7cc2',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Sweet Lovin' - Radio Edit",
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/afd0c02d7e875035485ca3e148f62634e7ea0c40?cid=a27687307e844539aa43816a9593ec0e',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:1qp0ptMXNg9hqLH8sk7cc2'}]}]

# %%
top_tr
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CCwRZC6euC8Odo6y9X8jr'},
#       'href': 'https://api.spotify.com/v1/artists/5CCwRZC6euC8Odo6y9X8jr',
#       'id': '5CCwRZC6euC8Odo6y9X8jr',
#       'name': 'Rita Ora',
#       'type': 'artist',
#       'uri': 'spotify:artist:5CCwRZC6euC8Odo6y9X8jr'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2iylTVQEMYGQ9CUgn9MAAT'},
#     'href': 'https://api.spotify.com/v1/albums/2iylTVQEMYGQ9CUgn9MAAT',
#     'id': '2iylTVQEMYGQ9CUgn9MAAT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f27f159d52482679d2bf2985',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f27f159d52482679d2bf2985',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f27f159d52482679d2bf2985',
#       'width': 64}],
#     'name': 'You for Me',
#     'release_date': '2021-07-02',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2iylTVQEMYGQ9CUgn9MAAT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CCwRZC6euC8Odo6y9X8jr'},
#      'href': 'https://api.spotify.com/v1/artists/5CCwRZC6euC8Odo6y9X8jr',
#      'id': '5CCwRZC6euC8Odo6y9X8jr',
#      'name': 'Rita Ora',
#      'type': 'artist',
#      'uri': 'spotify:artist:5CCwRZC6euC8Odo6y9X8jr'}],
#    'disc_number': 1,
#    'duration_ms': 175435,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEN2100072'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/73QyyUMMvtNELmULI4FOsp'},
#    'href': 'https://api.spotify.com/v1/tracks/73QyyUMMvtNELmULI4FOsp',
#    'id': '73QyyUMMvtNELmULI4FOsp',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'You for Me',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1e5fdf060cdb3ba52d6e3e9f2c0eb96fe5529171?cid=a27687307e844539aa43816a9593ec0e',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:73QyyUMMvtNELmULI4FOsp'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4IWBUUAFIplrNtaOHcJPRM'},
#       'href': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM',
#       'id': '4IWBUUAFIplrNtaOHcJPRM',
#       'name': 'James Arthur',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IWBUUAFIplrNtaOHcJPRM'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/262JcveAzA4ngibAS3Ocm8'},
#     'href': 'https://api.spotify.com/v1/albums/262JcveAzA4ngibAS3Ocm8',
#     'id': '262JcveAzA4ngibAS3Ocm8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c81e8266fc5973137c314afc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c81e8266fc5973137c314afc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c81e8266fc5973137c314afc',
#       'width': 64}],
#     'name': 'Lasting Lover',
#     'release_date': '2020-09-04',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:262JcveAzA4ngibAS3Ocm8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4IWBUUAFIplrNtaOHcJPRM'},
#      'href': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM',
#      'id': '4IWBUUAFIplrNtaOHcJPRM',
#      'name': 'James Arthur',
#      'type': 'artist',
#      'uri': 'spotify:artist:4IWBUUAFIplrNtaOHcJPRM'}],
#    'disc_number': 1,
#    'duration_ms': 218358,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEN2000076'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0DmAvNCAK08oCi7miSZUIY'},
#    'href': 'https://api.spotify.com/v1/tracks/0DmAvNCAK08oCi7miSZUIY',
#    'id': '0DmAvNCAK08oCi7miSZUIY',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Lasting Lover',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d1b8e3f81518223c8d693037fcdaf6acdee081c7?cid=a27687307e844539aa43816a9593ec0e',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0DmAvNCAK08oCi7miSZUIY'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73eAAfRkS2Vi4hx68oTJJE'},
#       'href': 'https://api.spotify.com/v1/artists/73eAAfRkS2Vi4hx68oTJJE',
#       'id': '73eAAfRkS2Vi4hx68oTJJE',
#       'name': 'John K',
#       'type': 'artist',
#       'uri': 'spotify:artist:73eAAfRkS2Vi4hx68oTJJE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1iCPJ4fkyZ5yvIWSqA4ajE'},
#     'href': 'https://api.spotify.com/v1/albums/1iCPJ4fkyZ5yvIWSqA4ajE',
#     'id': '1iCPJ4fkyZ5yvIWSqA4ajE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732fcfbea37325d667e877addb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022fcfbea37325d667e877addb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512fcfbea37325d667e877addb',
#       'width': 64}],
#     'name': 'if we never met (remix)',
#     'release_date': '2020-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1iCPJ4fkyZ5yvIWSqA4ajE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73eAAfRkS2Vi4hx68oTJJE'},
#      'href': 'https://api.spotify.com/v1/artists/73eAAfRkS2Vi4hx68oTJJE',
#      'id': '73eAAfRkS2Vi4hx68oTJJE',
#      'name': 'John K',
#      'type': 'artist',
#      'uri': 'spotify:artist:73eAAfRkS2Vi4hx68oTJJE'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#    'disc_number': 1,
#    'duration_ms': 186594,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM12000715'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0o6NlHNV7Tet6yh9BC6BGd'},
#    'href': 'https://api.spotify.com/v1/tracks/0o6NlHNV7Tet6yh9BC6BGd',
#    'id': '0o6NlHNV7Tet6yh9BC6BGd',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'if we never met - remix',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ff15c413fd14afb60b93361d66418aab3fb584a9?cid=a27687307e844539aa43816a9593ec0e',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0o6NlHNV7Tet6yh9BC6BGd'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EPJlUEBy49EX1wuFOvtjK'},
#       'href': 'https://api.spotify.com/v1/artists/4EPJlUEBy49EX1wuFOvtjK',
#       'id': '4EPJlUEBy49EX1wuFOvtjK',
#       'name': 'Becky Hill',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EPJlUEBy49EX1wuFOvtjK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2LWAzUYdZSUq0fW8ddbL1Q'},
#     'href': 'https://api.spotify.com/v1/albums/2LWAzUYdZSUq0fW8ddbL1Q',
#     'id': '2LWAzUYdZSUq0fW8ddbL1Q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273afeb6f4556e7125e4272780f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02afeb6f4556e7125e4272780f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851afeb6f4556e7125e4272780f',
#       'width': 64}],
#     'name': 'Only Honest On The Weekend',
#     'release_date': '2021-08-27',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:2LWAzUYdZSUq0fW8ddbL1Q'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EPJlUEBy49EX1wuFOvtjK'},
#      'href': 'https://api.spotify.com/v1/artists/4EPJlUEBy49EX1wuFOvtjK',
#      'id': '4EPJlUEBy49EX1wuFOvtjK',
#      'name': 'Becky Hill',
#      'type': 'artist',
#      'uri': 'spotify:artist:4EPJlUEBy49EX1wuFOvtjK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#    'disc_number': 1,
#    'duration_ms': 193360,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71906426'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ksheDQWyWfjG5ETO0aokW'},
#    'href': 'https://api.spotify.com/v1/tracks/4ksheDQWyWfjG5ETO0aokW',
#    'id': '4ksheDQWyWfjG5ETO0aokW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Heaven On My Mind (with Sigala)',
#    'popularity': 59,
#    'preview_url': None,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:4ksheDQWyWfjG5ETO0aokW'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5rr0xAQfk01cPi1N37jX11'},
#     'href': 'https://api.spotify.com/v1/albums/5rr0xAQfk01cPi1N37jX11',
#     'id': '5rr0xAQfk01cPi1N37jX11',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273681d6da9a0ab5ff23fadf0f9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02681d6da9a0ab5ff23fadf0f9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851681d6da9a0ab5ff23fadf0f9',
#       'width': 64}],
#     'name': 'Brighter Days',
#     'release_date': '2018-09-28',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5rr0xAQfk01cPi1N37jX11'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#    'disc_number': 1,
#    'duration_ms': 229813,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEN1500481'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5s7xgzXtmY4gMjeSlgisjy'},
#    'href': 'https://api.spotify.com/v1/tracks/5s7xgzXtmY4gMjeSlgisjy',
#    'id': '5s7xgzXtmY4gMjeSlgisjy',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Easy Love',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6d19019e3cf1fc3e8cf5ecc86029020d51151c7e?cid=a27687307e844539aa43816a9593ec0e',
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:5s7xgzXtmY4gMjeSlgisjy'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nDsS0l5ZAzMedVRKPP8F1'},
#       'href': 'https://api.spotify.com/v1/artists/7nDsS0l5ZAzMedVRKPP8F1',
#       'id': '7nDsS0l5ZAzMedVRKPP8F1',
#       'name': 'Ella Henderson',
#       'type': 'artist',
#       'uri': 'spotify:artist:7nDsS0l5ZAzMedVRKPP8F1'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4GtslEn7rHERVWRlqrYehy'},
#     'href': 'https://api.spotify.com/v1/albums/4GtslEn7rHERVWRlqrYehy',
#     'id': '4GtslEn7rHERVWRlqrYehy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273002753665f089902cc74cbe6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02002753665f089902cc74cbe6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851002753665f089902cc74cbe6',
#       'width': 64}],
#     'name': 'We Got Love',
#     'release_date': '2019-11-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4GtslEn7rHERVWRlqrYehy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nDsS0l5ZAzMedVRKPP8F1'},
#      'href': 'https://api.spotify.com/v1/artists/7nDsS0l5ZAzMedVRKPP8F1',
#      'id': '7nDsS0l5ZAzMedVRKPP8F1',
#      'name': 'Ella Henderson',
#      'type': 'artist',
#      'uri': 'spotify:artist:7nDsS0l5ZAzMedVRKPP8F1'}],
#    'disc_number': 1,
#    'duration_ms': 213040,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEN1900077'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/35mMXfym6C9VOTUVrcKKZp'},
#    'href': 'https://api.spotify.com/v1/tracks/35mMXfym6C9VOTUVrcKKZp',
#    'id': '35mMXfym6C9VOTUVrcKKZp',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'We Got Love',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8b80c3a06c8e4376e90dc69622008210f040c907?cid=a27687307e844539aa43816a9593ec0e',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:35mMXfym6C9VOTUVrcKKZp'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4EPJlUEBy49EX1wuFOvtjK'},
#       'href': 'https://api.spotify.com/v1/artists/4EPJlUEBy49EX1wuFOvtjK',
#       'id': '4EPJlUEBy49EX1wuFOvtjK',
#       'name': 'Becky Hill',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EPJlUEBy49EX1wuFOvtjK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1yZZdubJ2rovC4QIBP8riQ'},
#     'href': 'https://api.spotify.com/v1/albums/1yZZdubJ2rovC4QIBP8riQ',
#     'id': '1yZZdubJ2rovC4QIBP8riQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27317ee64e0de457686c3c247cd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0217ee64e0de457686c3c247cd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485117ee64e0de457686c3c247cd',
#       'width': 64}],
#     'name': 'Wish You Well',
#     'release_date': '2019-05-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1yZZdubJ2rovC4QIBP8riQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4EPJlUEBy49EX1wuFOvtjK'},
#      'href': 'https://api.spotify.com/v1/artists/4EPJlUEBy49EX1wuFOvtjK',
#      'id': '4EPJlUEBy49EX1wuFOvtjK',
#      'name': 'Becky Hill',
#      'type': 'artist',
#      'uri': 'spotify:artist:4EPJlUEBy49EX1wuFOvtjK'}],
#    'disc_number': 1,
#    'duration_ms': 205653,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEN1900019'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1yAPglN5AGf7UoLK062ZYq'},
#    'href': 'https://api.spotify.com/v1/tracks/1yAPglN5AGf7UoLK062ZYq',
#    'id': '1yAPglN5AGf7UoLK062ZYq',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Wish You Well',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/56962f8e1d8b7ade550d80701b2eeea60b88e370?cid=a27687307e844539aa43816a9593ec0e',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1yAPglN5AGf7UoLK062ZYq'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#       'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#       'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#       'name': 'R3HAB',
#       'type': 'artist',
#       'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYGAK2zu9EAomwj3hXkXy'},
#       'href': 'https://api.spotify.com/v1/artists/4kYGAK2zu9EAomwj3hXkXy',
#       'id': '4kYGAK2zu9EAomwj3hXkXy',
#       'name': 'JP Cooper',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYGAK2zu9EAomwj3hXkXy'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0HarHaqweXXH7ddIY6EX77'},
#     'href': 'https://api.spotify.com/v1/albums/0HarHaqweXXH7ddIY6EX77',
#     'id': '0HarHaqweXXH7ddIY6EX77',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27353a2dce47d2089a9e567436d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0253a2dce47d2089a9e567436d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485153a2dce47d2089a9e567436d',
#       'width': 64}],
#     'name': 'Runaway (with Sigala & JP Cooper)',
#     'release_date': '2021-08-20',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0HarHaqweXXH7ddIY6EX77'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#      'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#      'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#      'name': 'R3HAB',
#      'type': 'artist',
#      'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYGAK2zu9EAomwj3hXkXy'},
#      'href': 'https://api.spotify.com/v1/artists/4kYGAK2zu9EAomwj3hXkXy',
#      'id': '4kYGAK2zu9EAomwj3hXkXy',
#      'name': 'JP Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kYGAK2zu9EAomwj3hXkXy'}],
#    'disc_number': 1,
#    'duration_ms': 168196,
#    'explicit': False,
#    'external_ids': {'isrc': 'AEA2D2100063'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5H8fYiRySoxCnsjVzV67HO'},
#    'href': 'https://api.spotify.com/v1/tracks/5H8fYiRySoxCnsjVzV67HO',
#    'id': '5H8fYiRySoxCnsjVzV67HO',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Runaway (with Sigala & JP Cooper)',
#    'popularity': 67,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5H8fYiRySoxCnsjVzV67HO'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5rr0xAQfk01cPi1N37jX11'},
#     'href': 'https://api.spotify.com/v1/albums/5rr0xAQfk01cPi1N37jX11',
#     'id': '5rr0xAQfk01cPi1N37jX11',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273681d6da9a0ab5ff23fadf0f9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02681d6da9a0ab5ff23fadf0f9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851681d6da9a0ab5ff23fadf0f9',
#       'width': 64}],
#     'name': 'Brighter Days',
#     'release_date': '2018-09-28',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5rr0xAQfk01cPi1N37jX11'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/66TrUkUZ3RM29dqeDQRgyA'},
#      'href': 'https://api.spotify.com/v1/artists/66TrUkUZ3RM29dqeDQRgyA',
#      'id': '66TrUkUZ3RM29dqeDQRgyA',
#      'name': 'Ella Eyre',
#      'type': 'artist',
#      'uri': 'spotify:artist:66TrUkUZ3RM29dqeDQRgyA'}],
#    'disc_number': 1,
#    'duration_ms': 203386,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEN1700157'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0mGJTKRIuCOJtiT4YkJHiv'},
#    'href': 'https://api.spotify.com/v1/tracks/0mGJTKRIuCOJtiT4YkJHiv',
#    'id': '0mGJTKRIuCOJtiT4YkJHiv',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Came Here for Love',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2d88d0999e45021573b20f7bafa5afcf6210b1cb?cid=a27687307e844539aa43816a9593ec0e',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0mGJTKRIuCOJtiT4YkJHiv'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#       'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#       'id': '1IueXOQyABrMOprrzwQJWN',
#       'name': 'Sigala',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5rr0xAQfk01cPi1N37jX11'},
#     'href': 'https://api.spotify.com/v1/albums/5rr0xAQfk01cPi1N37jX11',
#     'id': '5rr0xAQfk01cPi1N37jX11',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273681d6da9a0ab5ff23fadf0f9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02681d6da9a0ab5ff23fadf0f9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851681d6da9a0ab5ff23fadf0f9',
#       'width': 64}],
#     'name': 'Brighter Days',
#     'release_date': '2018-09-28',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5rr0xAQfk01cPi1N37jX11'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7mWMzxN6IAIQ1tfFFtAiQv'},
#      'href': 'https://api.spotify.com/v1/artists/7mWMzxN6IAIQ1tfFFtAiQv',
#      'id': '7mWMzxN6IAIQ1tfFFtAiQv',
#      'name': 'Bryn Christopher',
#      'type': 'artist',
#      'uri': 'spotify:artist:7mWMzxN6IAIQ1tfFFtAiQv'}],
#    'disc_number': 1,
#    'duration_ms': 202213,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEN1501213'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1qp0ptMXNg9hqLH8sk7cc2'},
#    'href': 'https://api.spotify.com/v1/tracks/1qp0ptMXNg9hqLH8sk7cc2',
#    'id': '1qp0ptMXNg9hqLH8sk7cc2',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Sweet Lovin' - Radio Edit",
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/afd0c02d7e875035485ca3e148f62634e7ea0c40?cid=a27687307e844539aa43816a9593ec0e',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:1qp0ptMXNg9hqLH8sk7cc2'}]}

# %%
top_tracks_df=pd.DataFrame(top_tr["tracks"])
top_tracks_df.head()
# Out:
#                                                album  \
# 0  {'album_type': 'single', 'artists': [{'externa...
# 1  {'album_type': 'single', 'artists': [{'externa...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       175435     False  {'isrc': 'GBCEN2100072'}
# 1       218358     False  {'isrc': 'GBCEN2000076'}
# 2       186594     False  {'isrc': 'USSM12000715'}
# 3       193360     False  {'isrc': 'GBUM71906426'}
# 4       229813     False  {'isrc': 'GBCEN1500481'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/73...
# 1  {'spotify': 'https://open.spotify.com/track/0D...
# 2  {'spotify': 'https://open.spotify.com/track/0o...
# 3  {'spotify': 'https://open.spotify.com/track/4k...
# 4  {'spotify': 'https://open.spotify.com/track/5s...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/73QyyUMMvtNE...  73QyyUMMvtNELmULI4FOsp
# 1  https://api.spotify.com/v1/tracks/0DmAvNCAK08o...  0DmAvNCAK08oCi7miSZUIY
# 2  https://api.spotify.com/v1/tracks/0o6NlHNV7Tet...  0o6NlHNV7Tet6yh9BC6BGd
# 3  https://api.spotify.com/v1/tracks/4ksheDQWyWfj...  4ksheDQWyWfjG5ETO0aokW
# 4  https://api.spotify.com/v1/tracks/5s7xgzXtmY4g...  5s7xgzXtmY4gMjeSlgisjy
#
#    is_local  is_playable                             name  popularity  \
# 0     False         True                       You for Me          78
# 1     False         True                    Lasting Lover          78
# 2     False         True          if we never met - remix          68
# 3     False         True  Heaven On My Mind (with Sigala)          59
# 4     False         True                        Easy Love          67
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/1e5fdf060cdb3ba5...             1  track
# 1  https://p.scdn.co/mp3-preview/d1b8e3f81518223c...             1  track
# 2  https://p.scdn.co/mp3-preview/ff15c413fd14afb6...             1  track
# 3                                               None            13  track
# 4  https://p.scdn.co/mp3-preview/6d19019e3cf1fc3e...            16  track
#
#                                     uri
# 0  spotify:track:73QyyUMMvtNELmULI4FOsp
# 1  spotify:track:0DmAvNCAK08oCi7miSZUIY
# 2  spotify:track:0o6NlHNV7Tet6yh9BC6BGd
# 3  spotify:track:4ksheDQWyWfjG5ETO0aokW
# 4  spotify:track:5s7xgzXtmY4gMjeSlgisjy
